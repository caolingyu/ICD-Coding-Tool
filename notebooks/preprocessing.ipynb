# %% [markdown]
# # 中文数据预处理

# %% [markdown]
# ### 导入所需的包

# %%
# coding=utf-8
import sys
sys.path.append('../')
import datasets
from preprocessing import build_vocab
from preprocessing import vocab_index_descriptions
from constants import DATA_DIR

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import jieba
from sklearn.model_selection import train_test_split

from collections import Counter, defaultdict
import csv
import math
import operator
import importlib

# %% [markdown]
# ### 首先将三个文件导入pandas.dataframe并合并、提取所需的列

# %%
data_path1 = "../data/2014首页.csv"
data_path2 = "../data/2015首页.csv"
data_path3 = "../data/2016首页.csv"
df1 = pd.read_csv(data_path1, engine='python', encoding='gb18030')
df2 = pd.read_csv(data_path2, engine='python', encoding='gb18030')
df3 = pd.read_csv(data_path3, engine='python', encoding='gb18030')
df = pd.concat([df1, df2, df3], ignore_index=True)
df_main = df[['MAIN_DIAG','MAIN_ICD_CODE']]
print(len(df_main))
# Out:
# 242877

# %% [markdown]
# ### 筛选出code频数大于threashold对应的记录，去除部分code后面的+符号

# %%
threshold = 100
value_counts = df_main['MAIN_ICD_CODE'].value_counts()
# to_remove = value_counts[value_counts <= threshold].index
to_remove = value_counts[50:].index
df_main = df_main.loc[~df_main['MAIN_ICD_CODE'].isin(to_remove),:]
df_main = df_main.dropna(axis=0, how='any')
df_main = df_main.applymap(lambda x: x.strip('+') if type(x) is str else x)
df_main = df_main.reset_index(drop=True)
value_counts_after = df_main['MAIN_ICD_CODE'].value_counts()
# df_main['MAIN_ICD_CODE'].value_counts()
print(len(df_main))
print(value_counts_after.index.values)
df_main.head()
# Out:
# 101131
# ['Z51.102' 'Z51.100' 'J18.000' 'B08.401' 'O80.000' 'D25.900' 'O42.900'
#  'P23.900' 'O34.201' 'Z36.001' 'K40.901' 'J18.900' 'O04.900' 'I63.900'
#  'H25.900' 'P39.900' 'P59.901' 'Z51.901' 'C34.900' 'Z51.1' 'E04.902'
#  'C50.900' 'O70.000' 'G45.004' 'N60.201' 'N40.x00' 'I63.905' 'J06.900'
#  'J98.414' 'D06.900' 'C20.x00' 'K80.101' 'D27.x00' 'I84.201' 'M81.901'
#  'O24.900' 'J38.102' 'G40.901' 'Z47.001' 'C73.x00' 'C53.900' 'I25.901'
#  'C22.000' 'O82.000' 'P22.001' 'K80.000' 'J44.100' 'Z51.801' 'J03.901'
#  'I20.000']
#                      MAIN_DIAG MAIN_ICD_CODE
# 0                        新生儿肺炎       P23.900
# 1               急性右额叶、胼胝体右侧部梗塞       I63.900
# 2  非霍奇金淋巴瘤Ⅳ期B组（T淋巴母细胞性）并淋巴瘤白血病       Z51.901
# 3                         胎膜早破       O42.900
# 4                        支气管肺炎       J18.000

# %% [markdown]
# ### 对诊断描述进行分词并统计

# %%
jieba.load_userdict('../preprocessing/dict.txt')
df_main['DIAG_SPLIT'] = ""
for row in df_main.itertuples():
    cut = jieba.cut(row[1])
    diag_split = ' '.join(cut)
    df_main.loc[row[0]]['DIAG_SPLIT'] = diag_split
df_main.head()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/lg/qxn9gw8j7x75pddgvfpgbfg40000gn/T/jieba.cache
# Loading model cost 1.209 seconds.
# Prefix dict has been built succesfully.
#                      MAIN_DIAG MAIN_ICD_CODE  \
# 0                        新生儿肺炎       P23.900
# 1               急性右额叶、胼胝体右侧部梗塞       I63.900
# 2  非霍奇金淋巴瘤Ⅳ期B组（T淋巴母细胞性）并淋巴瘤白血病       Z51.901
# 3                         胎膜早破       O42.900
# 4                        支气管肺炎       J18.000
#
#                                  DIAG_SPLIT
# 0                                     新生儿肺炎
# 1                     急性 右 额叶 、 胼胝体 右侧 部 梗塞
# 2  非霍奇金淋巴瘤 Ⅳ 期 B 组 （ T 淋巴 母细胞 性 ） 并 淋巴瘤 白血病
# 3                                      胎膜早破
# 4                                     支气管肺炎

# %%
#Tokens and types
types = set()
num_tok = 0
for row in df_main.itertuples():
    for w in row[3].split():
        types.add(w)
        num_tok += 1

# %%
print("Num types", len(types))
print("Num tokens", str(num_tok))
# Out:
# Num types 5927
# Num tokens 722792

# %% [markdown]
# ### 划分训练集和测试集、建立词汇表

# %%
train, test = train_test_split(df_main, test_size=0.2)
train.to_csv('../data/train_raw.csv', index=False, encoding='gb18030')
test.to_csv('../data/test_raw.csv', index=False, encoding='gb18030')

# %%
importlib.reload(build_vocab)
vocab_min = 3
train_file = '../data/train_raw.csv'
vname = '../data/vocab.csv'
build_vocab.build_vocab(vocab_min, train_file, vname)
# Out:
# reading in data...
# removing rare terms
# 3269 terms qualify out of 5545 total
# writing output

# %%
with open('../data/code_list.csv', 'w', encoding='gb18030') as of:
    w = csv.writer(of)
    for code in code_list:
        w.writerow([code])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4a16175b7623> in <module>()
#       1 with open('../data/code_list.csv', 'w', encoding='gb18030') as of:
#       2     w = csv.writer(of)
# ----> 3     for code in code_list:
#       4         w.writerow([code])
#
# NameError: name 'code_list' is not defined

# %% [markdown]
# ### 导入ICD Description并对训练集和测试集再做筛选

# %%
importlib.reload(vocab_index_descriptions)
importlib.reload(datasets)
vocab_index_descriptions.vocab_index_descriptions('../data/vocab.csv',
                                                  '../data/description_vectors.vocab')
# Out:
# 100%|██████████| 23067/23067 [00:01<00:00, 14176.60it/s]

# %%
desc_code_list = []
with open("../data/description_vectors.vocab", 'r', encoding='gb18030') as vfile:
    r = csv.reader(vfile, delimiter=" ")
    next(r)
    for row in r:
        code = row[0]
        desc_code_list.append(code)

# %%
for splt in ['train', 'test']:
    filename = '../data/{}_raw.csv'.format(splt)
    df_temp = pd.read_csv(filename, encoding='gb18030')
#     df_temp = df_temp[df_temp['MAIN_ICD_CODE'].isin(desc_code_list)]
    df_temp['length'] = df_temp.apply(lambda row: len(str(row['DIAG_SPLIT']).split()), axis=1)
    df_temp = df_temp.sort_values(['length'])
    df_temp.to_csv('../data/{}.csv'.format(splt), index=False, encoding='gb18030')

# %%
df_train = pd.read_csv("../data/train.csv", engine='python', encoding='gb18030')
df_test = pd.read_csv("../data/test.csv", engine='python', encoding='gb18030')
code_list = df_train['MAIN_ICD_CODE'].value_counts().index.values
with open('../data/code_list.csv', 'w', encoding='gb18030') as of:
    w = csv.writer(of)
    for code in code_list:
        w.writerow([code])

# %% [markdown]
# # 测试区域

# %%
importlib.reload(datasets)
dicts = datasets.load_lookups('../data/train.csv', '../data/vocab.csv')
gen = datasets.data_generator('../data/train.csv', dicts, 8, num_labels=len(code_list), desc_embed=False)

# %%
for batch_idx, tup in enumerate(gen):
    data, target, _, code_set, descs = tup

# %%
len(code_list)
# Out:
# 50

# %%
desc_dict = defaultdict(str)
desc_code_list2 = []
with open('../data/ICD_Descriptions.csv', 'r', encoding='gb18030') as labelfile:
    f = csv.reader(labelfile)
    next(f)
    for row in f:
        code = row[0] if row[0] != '' else row[1]
        code = code.strip('_')
        #code = reformat(row[0])
        if code not in desc_dict.keys():
            desc_dict[code] = ' '.join(row[2:])
for code, desc in desc_dict.items():
#     print(code)
    desc_code_list2.append(code)
print(len(desc_code_list2))

data_code_list = []
with open('../data/code_list.csv', 'r', encoding='gb18030') as codefile:
    f = csv.reader(codefile)
    for row in f:
        data_code_list.append(row[0])

for c in data_code_list:
    if c not in desc_code_list:
        print(c)
# Out:
# 23067
# Z51.1
# M81.901
# G40.901
# P22.001
# QTZD1
# J44.101
# Z92.8
# O28.001
# D69.404
# O14.102
# z51.102
# J45.904
# N64.901
# N05.901
# M71.201
# A86.X00
# z51.100

# %%
ind2w = defaultdict(str)
with open('../data/vocab.csv', 'r', encoding='gb18030') as vocabfile:
    for i,line in enumerate(vocabfile):
        line = line.rstrip()
        if line != '':
            ind2w[i+1] = line.rstrip()
w2ind = {w:i for i,w in ind2w.items()}
print(ind2w)
print(w2ind)
# Out:
# defaultdict(<class 'str'>, {1: '乙状结肠', 2: '腺癌', 3: '累及', 4: '膀胱', 5: '顶壁', 6: '化疗', 7: '后', 8: 'P', 9: '-', 10: 'T4bN0M0', 11: 'IIC', 12: '期', 13: '食管', 14: '上', 15: '段', 16: '鳞癌', 17: '左乳', 18: '浸润性', 19: '导管', 20: '癌', 21: 'T4bN3M0', 22: 'IIIC', 23: '右', 24: '下叶', 25: '中央', 26: '型', 27: '肺', 28: '（', 29: 'T1aN1M0IIA', 30: '）', 31: '术后', 32: '急性', 33: 'B', 34: '淋巴细胞', 35: '白血病', 36: '左', 37: '乳腺', 38: '腺病', 39: '并', 40: '感染', 41: '、', 42: '脓肿', 43: '形成', 44: 'G2P2', 45: '宫内', 46: '妊娠', 47: '41', 48: '+', 49: '2', 50: '周', 51: 'LOA', 52: '，', 53: '顺娩', 54: '；', 55: '胃窦', 56: '局部', 57: '切除术', 58: '子宫', 59: '肌瘤', 60: '右上', 61: '双', 62: '肺门', 63: '纵隔', 64: '锁骨', 65: '淋巴结', 66: '转移', 67: 'c', 68: 'T1N3M0', 69: 'Ⅲ', 70: 'b', 71: '卵巢', 72: '浆液', 73: '性囊', 74: '腺瘤', 75: '左侧', 76: '基底节', 77: '区', 78: '脑出血', 79: '破入', 80: '脑室', 81: '上呼吸道', 82: '39', 83: '3', 84: '腘', 85: '窝', 86: '囊肿', 87: '右侧', 88: '精索', 89: '鞘', 90: '膜', 91: '积液', 92: '甲状腺', 93: '可能', 94: 'T2N3M0', 95: '右乳', 96: 'pT2N0M0', 97: 'IIA', 98: 'Luminal', 99: 'A型', 100: '巧克力', 101: '内膜', 102: 'Ia', 103: '(', 104: '部分', 105: '为', 106: 'II', 107: '性癌', 108: '脉管', 109: '癌栓', 110: ')', 111: '6', 112: '程', 113: '心律失常', 114: '：', 115: '阵发性', 116: '快速', 117: '房颤', 118: '伴', 119: '冠状动脉', 120: '性', 121: '心脏病', 122: '非', 123: 'ST', 124: '抬高', 125: '心肌梗塞', 126: 'I', 127: '°', 128: '级', 129: '肾病', 130: '综合征', 131: '原发性', 132: '单纯', 133: '激素', 134: '敏感', 135: '第一次', 136: '复发', 137: 'G1P1', 138: '38', 139: '腹股沟', 140: '斜', 141: '疝', 142: '胎膜', 143: '早破', 144: '发作', 145: '性疾病', 146: '癫痫', 147: '症状', 148: '慢性', 149: '支气管炎', 150: '阻塞性', 151: '肺气肿', 152: '双肺', 153: '多发', 154: '肺大泡', 155: '胸腔', 156: '双侧', 157: '自发', 158: 'Common', 159: '肺部', 160: '支气管', 161: '哮喘', 162: '盆', 163: '腹腔', 164: '腹膜', 165: '肝脏', 166: '胰头', 167: '多发性', 168: '混合', 169: '痔', 170: '结节性', 171: '甲状腺肿', 172: '嗜', 173: '酸性', 174: '肠套叠', 175: '颅内', 176: '区及', 177: '侧脑室', 178: '旁', 179: '右眼', 180: '孔源性', 181: '视网膜', 182: '脱离', 183: '右肺', 184: '继发', 185: '肺结核', 186: '空洞', 187: '咯血', 188: '进展', 189: '初治', 190: '痰', 191: '检', 192: '阳性', 193: '低', 194: '分化腺癌', 195: '幽门', 196: '梗阻', 197: 'T4aN2M0', 198: '输卵管', 199: '壶', 200: '腹部', 201: '破裂', 202: '出血', 203: '肺炎', 204: '脓毒', 205: '性休克', 206: '多', 207: '器官', 208: '功能障碍', 209: '早孕', 210: '双眼', 211: '老年性', 212: '白内障', 213: '畸胎瘤', 214: '早产儿', 215: 'AGA', 216: '瘢痕', 217: '胃', 218: '恶性肿瘤', 219: '胃角', 220: ',', 221: 'T4aN1M0', 222: 'A', 223: '骨盆', 224: '骨折', 225: '复位', 226: '内', 227: '固定', 228: '疾病', 229: '左肺', 230: '小', 231: '细胞', 232: '颅脑', 233: '胰腺', 234: '肾上腺', 235: 'cT4N3M1', 236: 'Ⅳ', 237: '广泛', 238: '不全', 239: '流产', 240: 'G2P1', 241: '40', 242: '剖宫产', 243: '桡骨', 244: '远端', 245: '开放性', 246: '1', 247: '.', 248: '左眼', 249: '玻璃体', 250: '切割', 251: '硅油', 252: '眼', 253: '周围', 254: '弥漫性', 255: '恶性', 256: 'C', 257: 'TxNxM1', 258: '细菌', 259: '真菌', 260: '连接处', 261: 'ypT4aN3M0IIIc', 262: '乳腺癌', 263: 'T2N2bM0', 264: 'IIIA', 265: '伴灶性', 266: '纤维', 267: '趋势', 268: '主', 269: '髂', 270: '下肢', 271: '动脉硬化', 272: '闭塞', 273: '症', 274: 'IIb', 275: '大', 276: '淋巴瘤', 277: '活化', 278: '来源', 279: '组', 280: '侵及', 281: '右锁', 282: '综合症', 283: '肠梗阻', 284: '先天性', 285: '巨', 286: '结肠', 287: '糖尿病', 288: '①', 289: '肾功能', 290: '②', 291: '周围神经', 292: '病变', 293: '③', 294: '④', 295: '心肌病', 296: '气管', 297: '及右', 298: '上叶', 299: '结核', 300: '手足', 301: '口病', 302: '神经系统', 303: '受累', 304: '不', 305: '典型', 306: '增生', 307: '待', 308: '除', 309: '胸中', 310: '损伤', 311: '额叶', 312: '颞叶', 313: '脑', 314: '挫裂伤', 315: '颞', 316: '部及', 317: '左额', 318: '顶', 319: '环状', 320: '新生儿', 321: '透明膜', 322: '病', 323: '化脓性', 324: '鼻窦炎', 325: '霉菌', 326: 'β', 327: '地中海', 328: '贫血', 329: '细菌性', 330: '肠炎', 331: '－', 332: '支原体', 333: '流感病毒', 334: '21', 335: '三体', 336: '高风险', 337: '宫颈', 338: '与', 339: '直肠', 340: '壁', 341: '消失', 342: '腹泻', 343: '高', 344: '胆红素', 345: '血症', 346: '直', 347: '癌伴', 348: '肝', 349: '全性', 350: 'T4aN2bM0', 351: '粪', 352: '石性', 353: '大脑', 354: '中', 355: '动脉', 356: '供血区', 357: '脑梗塞', 358: '功能', 359: '亢进症', 360: '—', 361: 'Graves', 362: '5',  ...
# {'乙状结肠': 1, '腺癌': 2, '累及': 3, '膀胱': 4, '顶壁': 5, '化疗': 6, '后': 7, 'P': 8, '-': 9, 'T4bN0M0': 10, 'IIC': 11, '期': 12, '食管': 13, '上': 14, '段': 15, '鳞癌': 16, '左乳': 17, '浸润性': 18, '导管': 19, '癌': 20, 'T4bN3M0': 21, 'IIIC': 22, '右': 23, '下叶': 24, '中央': 25, '型': 26, '肺': 27, '（': 28, 'T1aN1M0IIA': 29, '）': 30, '术后': 31, '急性': 32, 'B': 33, '淋巴细胞': 34, '白血病': 35, '左': 36, '乳腺': 37, '腺病': 38, '并': 39, '感染': 40, '、': 41, '脓肿': 42, '形成': 43, 'G2P2': 44, '宫内': 45, '妊娠': 46, '41': 47, '+': 48, '2': 49, '周': 50, 'LOA': 51, '，': 52, '顺娩': 53, '；': 54, '胃窦': 55, '局部': 56, '切除术': 57, '子宫': 58, '肌瘤': 59, '右上': 60, '双': 61, '肺门': 62, '纵隔': 63, '锁骨': 64, '淋巴结': 65, '转移': 66, 'c': 67, 'T1N3M0': 68, 'Ⅲ': 69, 'b': 70, '卵巢': 71, '浆液': 72, '性囊': 73, '腺瘤': 74, '左侧': 75, '基底节': 76, '区': 77, '脑出血': 78, '破入': 79, '脑室': 80, '上呼吸道': 81, '39': 82, '3': 83, '腘': 84, '窝': 85, '囊肿': 86, '右侧': 87, '精索': 88, '鞘': 89, '膜': 90, '积液': 91, '甲状腺': 92, '可能': 93, 'T2N3M0': 94, '右乳': 95, 'pT2N0M0': 96, 'IIA': 97, 'Luminal': 98, 'A型': 99, '巧克力': 100, '内膜': 101, 'Ia': 102, '(': 103, '部分': 104, '为': 105, 'II': 106, '性癌': 107, '脉管': 108, '癌栓': 109, ')': 110, '6': 111, '程': 112, '心律失常': 113, '：': 114, '阵发性': 115, '快速': 116, '房颤': 117, '伴': 118, '冠状动脉': 119, '性': 120, '心脏病': 121, '非': 122, 'ST': 123, '抬高': 124, '心肌梗塞': 125, 'I': 126, '°': 127, '级': 128, '肾病': 129, '综合征': 130, '原发性': 131, '单纯': 132, '激素': 133, '敏感': 134, '第一次': 135, '复发': 136, 'G1P1': 137, '38': 138, '腹股沟': 139, '斜': 140, '疝': 141, '胎膜': 142, '早破': 143, '发作': 144, '性疾病': 145, '癫痫': 146, '症状': 147, '慢性': 148, '支气管炎': 149, '阻塞性': 150, '肺气肿': 151, '双肺': 152, '多发': 153, '肺大泡': 154, '胸腔': 155, '双侧': 156, '自发': 157, 'Common': 158, '肺部': 159, '支气管': 160, '哮喘': 161, '盆': 162, '腹腔': 163, '腹膜': 164, '肝脏': 165, '胰头': 166, '多发性': 167, '混合': 168, '痔': 169, '结节性': 170, '甲状腺肿': 171, '嗜': 172, '酸性': 173, '肠套叠': 174, '颅内': 175, '区及': 176, '侧脑室': 177, '旁': 178, '右眼': 179, '孔源性': 180, '视网膜': 181, '脱离': 182, '右肺': 183, '继发': 184, '肺结核': 185, '空洞': 186, '咯血': 187, '进展': 188, '初治': 189, '痰': 190, '检': 191, '阳性': 192, '低': 193, '分化腺癌': 194, '幽门': 195, '梗阻': 196, 'T4aN2M0': 197, '输卵管': 198, '壶': 199, '腹部': 200, '破裂': 201, '出血': 202, '肺炎': 203, '脓毒': 204, '性休克': 205, '多': 206, '器官': 207, '功能障碍': 208, '早孕': 209, '双眼': 210, '老年性': 211, '白内障': 212, '畸胎瘤': 213, '早产儿': 214, 'AGA': 215, '瘢痕': 216, '胃': 217, '恶性肿瘤': 218, '胃角': 219, ',': 220, 'T4aN1M0': 221, 'A': 222, '骨盆': 223, '骨折': 224, '复位': 225, '内': 226, '固定': 227, '疾病': 228, '左肺': 229, '小': 230, '细胞': 231, '颅脑': 232, '胰腺': 233, '肾上腺': 234, 'cT4N3M1': 235, 'Ⅳ': 236, '广泛': 237, '不全': 238, '流产': 239, 'G2P1': 240, '40': 241, '剖宫产': 242, '桡骨': 243, '远端': 244, '开放性': 245, '1': 246, '.': 247, '左眼': 248, '玻璃体': 249, '切割': 250, '硅油': 251, '眼': 252, '周围': 253, '弥漫性': 254, '恶性': 255, 'C': 256, 'TxNxM1': 257, '细菌': 258, '真菌': 259, '连接处': 260, 'ypT4aN3M0IIIc': 261, '乳腺癌': 262, 'T2N2bM0': 263, 'IIIA': 264, '伴灶性': 265, '纤维': 266, '趋势': 267, '主': 268, '髂': 269, '下肢': 270, '动脉硬化': 271, '闭塞': 272, '症': 273, 'IIb': 274, '大': 275, '淋巴瘤': 276, '活化': 277, '来源': 278, '组': 279, '侵及': 280, '右锁': 281, '综合症': 282, '肠梗阻': 283, '先天性': 284, '巨': 285, '结肠': 286, '糖尿病': 287, '①': 288, '肾功能': 289, '②': 290, '周围神经': 291, '病变': 292, '③': 293, '④': 294, '心肌病': 295, '气管': 296, '及右': 297, '上叶': 298, '结核': 299, '手足': 300, '口病': 301, '神经系统': 302, '受累': 303, '不': 304, '典型': 305, '增生': 306, '待': 307, '除': 308, '胸中': 309, '损伤': 310, '额叶': 311, '颞叶': 312, '脑': 313, '挫裂伤': 314, '颞': 315, '部及': 316, '左额': 317, '顶': 318, '环状': 319, '新生儿': 320, '透明膜': 321, '病': 322, '化脓性': 323, '鼻窦炎': 324, '霉菌': 325, 'β': 326, '地中海': 327, '贫血': 328, '细菌性': 329, '肠炎': 330, '－': 331, '支原体': 332, '流感病毒': 333, '21': 334, '三体': 335, '高风险': 336, '宫颈': 337, '与': 338, '直肠': 339, '壁': 340, '消失': 341, '腹泻': 342, '高': 343, '胆红素': 344, '血症': 345, '直': 346, '癌伴': 347, '肝': 348, '全性': 349, 'T4aN2bM0': 350, '粪': 351, '石性': 352, '大脑': 353, '中': 354, '动脉': 355, '供血区': 356, '脑梗塞': 357, '功能': 358, '亢进症': 359, '—': 360, 'Graves': 361, '5': 362, 'T2N1MO': 363, 'IIB': 364,  ...

# %%
jieba.load_userdict('../preprocessing/dict.txt')
df_main['DIAG_SPLIT2'] = ""
for row in df_main.itertuples():
    cut = jieba.cut(row[1])
    diag_split = ' '.join(cut)
    df_main.loc[row[0]]['DIAG_SPLIT2'] = diag_split
df_main.head()
# Out:
#                      MAIN_DIAG MAIN_ICD_CODE  \
# 0                        新生儿肺炎       P23.900
# 1               急性右额叶、胼胝体右侧部梗塞       I63.900
# 2  非霍奇金淋巴瘤Ⅳ期B组（T淋巴母细胞性）并淋巴瘤白血病       Z51.901
# 3                     左肾上腺髓脂肪瘤       D35.000
# 4                        急性腹泻病       K52.916
#
#                                    DIAG_SPLIT  \
# 0                                      新生儿 肺炎
# 1                      急性 右 额叶 、 胼胝 体 右侧 部 梗塞
# 2  非 霍奇金 淋巴瘤 Ⅳ 期 B 组 （ T 淋巴 母细胞 性 ） 并 淋巴瘤 白血病
# 3                                 左 肾上腺 髓 脂肪瘤
# 4                                     急性 腹泻 病
#
#                                 DIAG_SPLIT2
# 0                                     新生儿肺炎
# 1                     急性 右 额叶 、 胼胝体 右侧 部 梗塞
# 2  非霍奇金淋巴瘤 Ⅳ 期 B 组 （ T 淋巴 母细胞 性 ） 并 淋巴瘤 白血病
# 3                               左 肾上腺 髓 脂肪瘤
# 4                                    急性腹泻 病

# %%
df_main.head(50)
# Out:
#                                             MAIN_DIAG MAIN_ICD_CODE  \
# 0                                               新生儿肺炎       P23.900
# 1                                      急性右额叶、胼胝体右侧部梗塞       I63.900
# 2                         非霍奇金淋巴瘤Ⅳ期B组（T淋巴母细胞性）并淋巴瘤白血病       Z51.901
# 3                                            左肾上腺髓脂肪瘤       D35.000
# 4                                               急性腹泻病       K52.916
# 5                                                胎膜早破       O42.900
# 6                                             左下肢静脉曲张       I83.900
# 7                                               支气管肺炎       J18.000
# 8                                   椎基动脉供血不足（左侧椎动脉硬化）       G45.002
# 9                          传染性单核细胞增多症(EB病毒感染+巨细胞病毒感染)       B27.900
# 10      双侧鼻骨、左上颌窦额突粉碎性骨折；鼻中隔骨折；右侧上颌窦各壁粉碎性骨折；右眶外壁、下壁骨折       S02.200
# 11  回盲部低分化腺癌（部分为印戒细胞癌）并盆腹腔、腹壁、大网膜多发转移P-T4aN2bM1b-IVB期         Z51.1
# 12                                       1、右腹股沟斜疝术后复发       K40.901
# 13                                      急性髓细胞性白血病部分缓解       Z51.901
# 14                                G1P1宫内妊娠38+1周ROA剖宫产       O82.900
# 15                     右上肺腺鳞癌术后左上肺转移（R—T1N2M1 IV期）化疗后       Z51.102
# 16                                 左侧额顶区慢性硬膜下血肿并大脑镰下疝       S06.501
# 17                           右乳腺浸润性导管癌（P-T2N0Mx）术后化疗后         Z51.1
# 18                                         左卵巢巧克力囊肿破裂       N83.201
# 19                                        右侧乳腺腺病并纤维腺瘤       N60.201
# 20                  回肠系膜多形性恶性纤维组织细胞瘤/未分化肉瘤并肝转移姑息术后 Ⅳ期         Z51.1
# 21             左上腹组织细胞肉瘤累及胃、横结肠、胰体尾、脾脏、腹腔、腹膜后姑息术后IV期；         Z51.1
# 22                          左上肺腺癌（P-T2N2M0IIIa期）术后化疗后       Z51.102
# 23                                           关节型过敏性紫癜       D69.002
# 24                                       左乳腺腺病（小叶增生型）       N60.201
# 25            胃窦中分化腺癌PT4N1M0 IIIa期并术后化疗肺部、肝脏多发转移 并残胃炎       Z51.102
# 26  右侧乳腺导管内癌术后多发转移rIV期（右侧锁骨上、右侧内乳区、纵隔、肝门区及腹膜后多发淋巴结...         Z51.1
# 27                                              支气管肺炎       J18.000
# 28                                          急性左侧颞叶脑出血       I61.900
# 29                   结节性甲状腺肿并甲亢 甲亢性心脏病 心律失常：偶发房早，短阵房速       E04.902
# 30                              1、贲门腺癌P-T4aN1M0-IIIA期       C16.000
# 31                                            感染性发热待查       B99.x01
# 32                                               双肺炎症       J18.900
# 33                                          右侧锁骨粉碎性骨折       S42.000
# 34                                   非霍奇金淋巴瘤（弥漫大B细胞性）       Z51.100
# 35                冠状动脉性心脏病：急性前间壁心梗，多支血管严重病变，Killip Ⅰ级       I25.103
# 36                                        右卵巢无性细胞瘤Ic期       C56.x00
# 37                                    直肠腺癌P-T2N0M0-I期       C20.x00
# 38                                         慢性胆囊炎、胆囊结石       K80.101
# 39                                            IgA肾病可能       N02.801
# 40                                              支气管肺炎       J18.000
# 41                                       支气管哮喘急性发作并感染       J45.904
# 42                                    胆囊息肉、胆囊结石并慢性胆囊炎       K82.802
# 43                                           左颞顶皮瓣下感染       T81.406
# 44                                      弥漫大B细胞淋巴瘤 ⅢS期         Z51.1
# 45                          贲门中分化管状腺癌根治术后p-T3N1M0 ⅡB期         Z51.1
# 46                                              支气管肺炎       J15.700
# 47                                            右侧腹股沟斜疝       K40.901
# 48                    膀胱粘液腺癌并印戒细胞癌局部切除术后局部复发并腹壁转移多次术后         Z51.1
# 49                              急性右侧额叶、岛叶及右侧侧脑室旁多发脑梗塞       I63.905
#
#                                            DIAG_SPLIT  \
# 0                                              新生儿 肺炎
# 1                              急性 右 额叶 、 胼胝 体 右侧 部 梗塞
# 2          非 霍奇金 淋巴瘤 Ⅳ 期 B 组 （ T 淋巴 母细胞 性 ） 并 淋巴瘤 白血病
# 3                                         左 肾上腺 髓 脂肪瘤
# 4                                             急性 腹泻 病
# 5                                               胎膜 早破
# 6                                           左 下肢 静脉曲张
# 7                                              支气管 肺炎
# 8                           椎基 动脉 供血 不足 （ 左侧 椎 动脉硬化 ）
# 9                传染性 单核细胞 增多 症 ( EB 病毒感染 + 巨细胞 病毒感染 )
# 10  双侧 鼻骨 、 左 上颌 窦额 突 粉碎性 骨折 ； 鼻中隔 骨折 ； 右侧 上颌 窦 各壁...
# 11  回盲部 低 分化腺癌 （ 部分 为 印戒 细胞 癌 ） 并盆 腹腔 、 腹壁 、 大 网膜 ...
# 12                                1 、 右 腹股沟 斜 疝 术后 复发
# 13                                急性 髓 细胞 性 白血病 部分 缓解
# 14                        G1P1 宫内 妊娠 38 + 1 周 ROA 剖宫产
# 15     右上 肺腺 鳞癌 术后 左上 肺 转移 （ R — T1N2M1   IV 期 ） 化疗 后
# 16                        左侧 额顶区 慢性 硬膜 下 血肿 并 大脑 镰下 疝
# 17               右 乳腺 浸润性 导管 癌 （ P - T2N0Mx ） 术后 化疗 后
# 18                                     左 卵巢 巧克力 囊肿 破裂
# 19                                   右侧 乳腺 腺病 并 纤维 腺瘤
# 20  回 肠系膜 多形性 恶性 纤维组织 细胞 瘤 / 未 分化 肉瘤 并 肝 转移 姑息 术后 ...
# 21  左 上腹 组织细胞 肉瘤 累及 胃 、 横结肠 、 胰体 尾 、 脾脏 、 腹腔 、 腹膜 ...
# 22               左上 肺 腺癌 （ P - T2N2M0IIIa 期 ） 术后 化疗 后
# 23                                        关节 型 过敏性 紫癜
# 24                                左 乳腺 腺病 （ 小叶 增生 型 ）
# 25  胃窦 中 分化腺癌 PT4N1M0   IIIa 期 并 术后 化疗 肺部 、 肝脏 多发 ...
# 26  右侧 乳腺 导管 内癌 术后 多发 转移 rIV 期 （ 右侧 锁骨 上 、 右侧 内乳区 ...
# 27                                             支气管 肺炎
# 28                                       急性 左侧 颞叶 脑出血
# 29    结节性 甲状腺肿 并 甲亢   甲亢 性 心脏病   心律失常 ： 偶发 房早 ， 短阵 房速
# 30                     1 、 贲门 腺癌 P - T4aN1M0 - IIIA 期
# 31                                          感染性 发热 待查
# 32                                              双肺 炎症
# 33                                       右侧 锁骨 粉碎性 骨折
# 34                          非 霍奇金 淋巴瘤 （ 弥漫 大 B 细胞 性 ）
# 35  冠状动脉 性 心脏病 ： 急性 前 间壁 心梗 ， 多支 血管 严重 病变 ， Killip...
# 36                                  右 卵巢 无性 细胞 瘤 Ic 期
# 37                             直肠 腺癌 P - T2N0M0 - I 期
# 38                                      慢性 胆囊炎 、 胆囊结石
# 39                                          IgA 肾病 可能
# 40                                             支气管 肺炎
# 41                                  支气管 哮喘 急性 发作 并 感染
# 42                               胆囊息肉 、 胆囊结石 并 慢性 胆囊炎
# 43                                      左 颞 顶 皮瓣 下 感染
# 44                              弥漫 大 B 细胞 淋巴瘤   Ⅲ S 期
# 45             贲门 中 分化 管状 腺癌 根治术 后 p - T3N1M0   Ⅱ B 期
# 46                                             支气管 肺炎
# 47                                         右侧 腹股沟 斜 疝
# 48     膀胱 粘液腺癌 并 印戒 细胞 癌 局部 切除术 后 局部 复发 并 腹壁 转移 多次 术后
# 49                     急性 右侧 额叶 、 岛叶及 右侧 侧脑室 旁 多发 脑梗塞
#
#                                           DIAG_SPLIT2
# 0                                               新生儿肺炎
# 1                               急性 右 额叶 、 胼胝体 右侧 部 梗塞
# 2            非霍奇金淋巴瘤 Ⅳ 期 B 组 （ T 淋巴 母细胞 性 ） 并 淋巴瘤 白血病
# 3                                         左 肾上腺 髓 脂肪瘤
# 4                                              急性腹泻 病
# 5                                                胎膜早破
# 6                                            左 下肢静脉曲张
# 7                                               支气管肺炎
# 8                            椎基 动脉 供血 不足 （ 左侧椎动脉 硬化 ）
# 9                     传染性单核细胞增多症 ( EB病毒感染 + 巨细胞病毒感染 )
# 10  双侧 鼻骨 、 左 上颌窦 额突 粉碎性骨折 ； 鼻中隔 骨折 ； 右侧 上颌窦 各壁 粉碎...
# 11  回 盲部 低 分化腺癌 （ 部分 为 印戒细胞癌 ） 并盆 腹腔 、 腹壁 、 大网膜 多发...
# 12                                  1 、 右 腹股沟斜疝 术后 复发
# 13                                急性 髓 细胞 性 白血病 部分 缓解
# 14                        G1P1 宫内 妊娠 38 + 1 周 ROA 剖宫产
# 15     右上 肺 腺鳞癌 术后 左上 肺 转移 （ R — T1N2M1   IV 期 ） 化疗 后
# 16                          左侧 额 顶区 慢性硬膜下血肿 并 大脑镰 下 疝
# 17                 右 乳腺 浸润性导管癌 （ P - T2N0Mx ） 术后 化疗 后
# 18                                        左 卵巢巧克力囊肿破裂
# 19                                     右侧 乳腺腺病 并 纤维腺瘤
# 20      回 肠系膜 多形性 恶性纤维组织细胞瘤 / 未分化肉瘤 并 肝转移 姑息 术后   Ⅳ 期
# 21  左上腹 组织细胞肉瘤 累及 胃 、 横结肠 、 胰体 尾 、 脾脏 、 腹腔 、 腹膜 后 ...
# 22               左上 肺 腺癌 （ P - T2N2M0IIIa 期 ） 术后 化疗 后
# 23                                         关节 型 过敏性紫癜
# 24                                  左 乳腺腺病 （ 小叶增生 型 ）
# 25  胃窦 中 分化腺癌 PT4N1M0   IIIa 期 并 术后 化疗 肺部 、 肝脏 多发 ...
# 26  右侧 乳腺 导管内癌 术后 多发 转移 rIV 期 （ 右侧 锁骨 上 、 右侧 内乳区 、...
# 27                                              支气管肺炎
# 28                                       急性 左侧 颞叶 脑出血
# 29     结节性甲状腺肿 并 甲亢   甲亢 性 心脏病   心律失常 ： 偶发 房早 ， 短阵 房速
# 30                     1 、 贲门 腺癌 P - T4aN1M0 - IIIA 期
# 31                                           感染性发热 待查
# 32                                              双肺 炎症
# 33                                        右侧 锁骨 粉碎性骨折
# 34                            非霍奇金淋巴瘤 （ 弥漫 大 B 细胞 性 ）
# 35  冠状动脉性心脏病 ： 急性 前 间壁 心梗 ， 多支 血管 严重 病变 ， Killip  ...
# 36                                     右卵巢 无性细胞瘤 Ic 期
# 37                             直肠 腺癌 P - T2N0M0 - I 期
# 38                                       慢性胆囊炎 、 胆囊结石
# 39                                           IgA肾病 可能
# 40                                              支气管肺炎
# 41                                  支气管 哮喘 急性 发作 并 感染
# 42                                胆囊息肉 、 胆囊结石 并 慢性胆囊炎
# 43                                      左 颞 顶 皮瓣 下 感染
# 44                                弥漫 大 B细胞淋巴瘤   Ⅲ S 期
# 45              贲门 中 分化 管状腺癌 根治术 后 p - T3N1M0   Ⅱ B 期
# 46                                              支气管肺炎
# 47                                           右侧 腹股沟斜疝
# 48       膀胱 粘液腺癌 并 印戒细胞癌 局部 切除术 后 局部 复发 并 腹壁 转移 多次 术后
# 49                    急性 右侧 额叶 、 岛叶 及 右侧 侧脑室 旁 多发 脑梗塞

# %%
df.head()
# Out:
#    PATIENT_ID   EVENT_NO  CASE_NO HOS_NAME  HOS_ID HEALTH_CARD  \
# 0     1980034  298842001   298842    zzsyy     NaN         NaN
# 1     1935493  291066001   291066    zzsyy     NaN         NaN
# 2     1936683  291222001   291222    zzsyy     NaN         NaN
# 3     1796991  270569006   270569    zzsyy     NaN         NaN
# 4     1928057  291400001   291400    zzsyy     NaN         NaN
#
#               ID_CARD   NAME SEX    BIRTHDAY    ...    FEE_CNZCY FEE_20  \
# 0                  未发  曾瑞荣之女   女  2014-02-13    ...          NaN    NaN
# 1  510902195607179313    余江龙   男  1954-12-19    ...          NaN    NaN
# 2  350622193411033021    李银丝   女  1934-11-03    ...          NaN    NaN
# 3                   /    林志联   男  1985-07-29    ...          NaN    NaN
# 4  350600196712133526     吴晔   女  1967-12-13    ...          NaN    NaN
#
#   FEE_21 FEE_22 FEE_23 FEE_24  FEE_25  FEE_26   FEE_27 FEE_OTHER
# 0    NaN    NaN    NaN    NaN   27.63  212.91      NaN      76.5
# 1    NaN    NaN    NaN    NaN  352.39  109.78      NaN       NaN
# 2    NaN    NaN    NaN    NaN  360.88  697.14      NaN       NaN
# 3    NaN    NaN    NaN    NaN    8.28  108.21      NaN       NaN
# 4    NaN    NaN    NaN    NaN   71.01  416.97  3115.32       NaN
#
# [5 rows x 233 columns]
